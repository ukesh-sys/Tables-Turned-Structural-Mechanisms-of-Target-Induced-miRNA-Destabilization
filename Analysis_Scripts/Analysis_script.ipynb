# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
ATF = pd.read_csv("../../distance_Com/ATF3_PAZ_MID_distance.txt", sep=' ', names=['Frame', 'Distance'])
HVS = pd.read_csv("../../distance_Com/HVS_PAZ_MID_distance.txt", sep=' ', names=['Frame', 'Distance'])
PIK2 = pd.read_csv("../../distance_Com/PIK2_PAZ_MID_distance.txt", sep=' ', names=['Frame', 'Distance'])
SZDR1 = pd.read_csv("../../distance_Com/SZDR1_PAZ_MID_distance.txt", sep=' ', names=['Frame', 'Distance'])
Only_miRNA= pd.read_csv("../../distance_Com/Only_miRNA_PAZ_MID_distance.txt", sep=' ', names=['Frame', 'Distance'])

plt.figure(figsize=(10, 8))

# Calculate rolling average with a window size of your choice (e.g., window=5)
window_size = 20

# Assuming ATF, HVS, PIK2, SZDR1, and Only_miRNA are pandas DataFrames
ATF['RollingAvg'] = ATF['Distance'].rolling(window=window_size).mean()
HVS['RollingAvg'] = HVS['Distance'].rolling(window=window_size).mean()
PIK2['RollingAvg'] = PIK2['Distance'].rolling(window=window_size).mean()
# SZDR1['RollingAvg'] = SZDR1['Distance'].rolling(window=window_size).mean()
Only_miRNA['RollingAvg'] = Only_miRNA['Distance'].rolling(window=window_size).mean()

# Plot the original data
# plt.plot(ATF['Frame'] / 2, ATF['Distance'], linestyle='-', color='k', label='ATF3')
# plt.plot(HVS['Frame'] / 2, HVS['Distance'], linestyle='-', color='orange', label='HVS')
# plt.plot(PIK2['Frame'] / 2, PIK2['Distance'], linestyle='-', color='red', label='PIK2')
# plt.plot(SZDR1['Frame'] / 2, SZDR1['Distance'], linestyle='-', color='yellow', label='SZDR1')
# plt.plot(Only_miRNA['Frame'] / 2, Only_miRNA['Distance'], linestyle='-', color='green', label='Only miRNA')

# Plot the rolling averages
plt.plot(Only_miRNA['Frame'] / 2, Only_miRNA['RollingAvg'], linestyle='-', color='red', label='Only miRNA',linewidth=3)
plt.plot(ATF['Frame'] / 2, ATF['RollingAvg'], linestyle='-', color='darkviolet', label='ATF3',linewidth=3)
plt.plot(PIK2['Frame'] / 2, PIK2['RollingAvg'], linestyle='-', color='darkgreen', label='PIK2',linewidth=3)
plt.plot(HVS['Frame'] / 2, HVS['RollingAvg'], linestyle='-', color='k', label='HVS',linewidth=3)
# plt.plot(SZDR1['Frame'] / 2, SZDR1['RollingAvg'], linestyle='--', color='fuchsia', label='SZDR1')

# Add labels and title
plt.xlabel('Time(ns)', fontsize=30)
plt.ylabel('Distance (Å)', fontsize=30)
plt.title('PAZ-MID domain distance', fontsize=28)
# plt.axvspan(400, 500, color='gray', alpha=0.3)
plt.xticks(fontsize=30)
plt.yticks([45,50,55,60,65],fontsize=30)

# Add a legend
plt.legend(fontsize=18, frameon=False)

# Add grid lines
# plt.grid(True)
plt.xlim(0, 500)
# plt.ylim(45, 72)

# Show the plot
plt.show()

# %%
RNAA_only_miRNA = pd.read_csv("../../Re_Analysis/Only_miRNA/namd/H-bonds_Analysis/RNAA_Only_miRNA_nucleic.dat", sep='   ')
RNAA_HVS = pd.read_csv("../../viron_simulation/namd/Analysis_Data/RNAA_viron_nucleic.dat", sep='   ')
RNAA_ATF3 = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RNAA_ATF3_nucleic.dat", sep='   ')
RNAA_PIK2 = pd.read_csv("../../PIK2_simulations/namd/Analysis_Data/RNAA_PIK2_nucleic.dat", sep='   ')
# RNAA_SZDR1 = pd.read_csv("../../Re_Analysis/szrd1/namd/H-bonds_analysis/RNAA_SZFR1_nucleic.dat", sep='   ')

plt.figure(figsize=(10, 8))

# Calculate rolling average with a window size of your choice (e.g., window=5)
window_size = 10

# Assuming RNAA_ATF3, RNAA_HVS, RNAA_PIK2, SZDR1, and RNAA_only_miRNA are pandas DataFrames
RNAA_ATF3['RollingAvg'] = RNAA_ATF3['mol12'].rolling(window=window_size).mean()
RNAA_HVS['RollingAvg'] = RNAA_HVS['mol14'].rolling(window=window_size).mean()
RNAA_PIK2['RollingAvg'] = RNAA_PIK2['mol15'].rolling(window=window_size).mean()
# SZDR1['RollingAvg'] = SZDR1['Distance'].rolling(window=window_size).mean()
RNAA_only_miRNA['RollingAvg'] = RNAA_only_miRNA['mol11'].rolling(window=window_size).mean()

# Plot the rolling averages
plt.plot(RNAA_only_miRNA['frame'] / 2, RNAA_only_miRNA['RollingAvg'], linestyle='-', color='red', label='Only miRNA',linewidth=3)
plt.plot(RNAA_ATF3['frame'] / 2, RNAA_ATF3['RollingAvg'], linestyle='-', color='darkviolet', label='ATF3',linewidth=3)
plt.plot(RNAA_PIK2['frame'] / 2, RNAA_PIK2['RollingAvg'], linestyle='-', color='darkgreen', label='PIK2',linewidth=3)
plt.plot(RNAA_HVS['frame'] / 2, RNAA_HVS['RollingAvg'], linestyle='-', color='k', label='HVS',linewidth=3)

# plt.plot(RNAA_only_miRNA['frame'] / 2, RNAA_only_miRNA['mol11'], linestyle='-', color='red', label='',alpha=0.2)
# plt.plot(RNAA_ATF3['frame'] / 2, RNAA_ATF3['mol12'], linestyle='-', color='darkviolet', label='',alpha=0.2)
# plt.plot(RNAA_PIK2['frame'] / 2, RNAA_PIK2['mol15'], linestyle='-', color='darkgreen', label='',alpha=0.2)
# plt.plot(RNAA_HVS['frame'] / 2, RNAA_HVS['mol14'], linestyle='-', color='grey', label='',alpha=0.2)
# # plt.plot(SZDR1['Frame'] / 2, SZDR1['RollingAvg'], linestyle='--', color='yellow', label='SZDR1')

# Add labels and title
plt.xlabel('Time(ns)', fontsize=30)
plt.ylabel('RMSD (Å)', fontsize=30)
plt.xticks(fontsize=30)
plt.yticks(fontsize=30)

# Add a legend and position it outside the plot
plt.legend(fontsize=17, loc='upper left', frameon=False)

# Add grid lines if needed (commented out)
# plt.grid(True)
plt.xlim(0, 500)
# plt.ylim(45, 70)

# Show the plot
plt.tight_layout()  # Adjust the plot to make room for the legend
plt.show()
# Out:
# C:\Users\17867\AppData\Local\Temp\ipykernel_17692\3785031352.py:1: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   RNAA_only_miRNA = pd.read_csv("../../Re_Analysis/Only_miRNA/namd/H-bonds_Analysis/RNAA_Only_miRNA_nucleic.dat", sep='   ')
# C:\Users\17867\AppData\Local\Temp\ipykernel_17692\3785031352.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   RNAA_HVS = pd.read_csv("../../viron_simulation/namd/Analysis_Data/RNAA_viron_nucleic.dat", sep='   ')
# ...

# %% [markdown]
# ## H Bond Analysis

# %%
three_to_one = {
    'ALA': 'A', 'ARG': 'R', 'ASN': 'N', 'ASP': 'D', 'CYS': 'C',
    'GLN': 'Q', 'GLU': 'E', 'GLY': 'G', 'HIS': 'H', 'ILE': 'I',
    'LEU': 'L', 'LYS': 'K', 'MET': 'M', 'PHE': 'F', 'PRO': 'P',
    'SER': 'S', 'THR': 'T', 'TRP': 'W', 'TYR': 'Y', 'VAL': 'V',
    'CYT':'CYT', 'ADE':'ADE','GUA':'GUA','URA':'URA', 'HSD':'H'
}
vmin = 0  # or use np.min([matrix_1, matrix_2]) to get the minimum value across all matrices
vmax = 175  # or use np.max([matrix_1, matrix_2]) to get the maximum value across all matrices
matrix_0 = pd.read_csv("temp/miRNA_1_to_7.csv",index_col=0)

# %% [markdown]
# ## MiRNA Only

# %%
sorted_columns = sorted(matrix_0.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_0.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_0=matrix_0[sorted_columns]
matrix_0 = matrix_0.loc[sorted_index]
matrix_0[matrix_0<45] =np.nan
columns = []
for colname in matrix_0.columns:
    columns.append(colname[0]+colname[-1])
    # Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))
matrix_0.columns = columns
heatmap = sns.heatmap(
    matrix_0,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": ""},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=50)  # Adjust tick label size

# Customize the rest of the plot
plt.xticks(fontsize=50, rotation=90)
plt.yticks(fontsize=50, rotation=0)
plt.xlabel('Nucleotides', fontsize=52)
plt.ylabel('Amino Acids', fontsize=52)
# plt.title("miRNA 1 to 7 nucleotides and protein (Only miRNA)", fontsize=17)

plt.show()

# %%
# matrix_0.to_csv("temp/miRNA_8_to_21.csv")
matrix_0 = pd.read_csv("temp/miRNA_8_to_21.csv",index_col=0)

sorted_columns = sorted(matrix_0.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_0.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_0=matrix_0[sorted_columns]
matrix_0 = matrix_0.loc[sorted_index]

matrix_0[matrix_0<45] =np.nan
matrix_0.drop(matrix_0[matrix_0.sum(axis=1) == 0].index, inplace=True)
matrix_0.drop(matrix_0.columns[matrix_0.sum(axis=0) == 0], axis=1, inplace=True)
columns = ['U8','G9','G10','A13','A14','G15','U17','C21']
# for colname in matrix_0.columns:
#     columns.append(colname[0]+colname[-1])
matrix_0.columns = columns

# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))

heatmap = sns.heatmap(
    matrix_0,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=50)  # Adjust tick label size

# Customize the rest of the plot
plt.xticks(fontsize=50, rotation=90)
plt.yticks(fontsize=50, rotation=0)
plt.xlabel('Nucleotides', fontsize=52)
plt.ylabel('Amino Acids', fontsize=52)
# plt.title("miRNA 8 to 21 nucleotides and protein (Only miRNA)", fontsize=20)

plt.show()

# %% [markdown]
# ## HSUR

# %%
# HSUR_100[1:]
HSUR_100 = pd.read_csv("../../viron_simulation/namd/H-bonds_file/1_to_7_PROA-RNAA_100ns_details.dat", sep='\t')
donor = HSUR_100['donor '].values
donors = []
acceptor = HSUR_100[' acceptor '].values
acceptors = []
for acc in acceptor:
    hyphen_index = acc.index('-')
    acceptors.append(acc[:hyphen_index])
for don in donor:
    #donors.append(don[:-6])
    hyphen_index = don.index('-')
    donors.append(don[:hyphen_index])
Nucleotides = []
for i in range(0,len(donors)):
    Nucleotides.append(donors[i][0:]+"_"+acceptors[i][1:])
HSUR_100['Nucleotides'] = Nucleotides
HSUR_100['Percentage'] = HSUR_100[' occupancy']
components = [x.split('_') for x in HSUR_100['Nucleotides']]

# Create a new DataFrame with the components and 'Percentage' column
new_HSUR_100_0 = pd.DataFrame(components, columns=['Donor', 'Acceptor'])
new_HSUR_100_0['Percentage'] = HSUR_100['Percentage']
new_HSUR_100_0['Percentage'] = new_HSUR_100_0['Percentage'].str.rstrip('%').astype(float)
matrix_HVS = new_HSUR_100_0.pivot_table(index='Donor', columns='Acceptor', values='Percentage', aggfunc='mean')
matrix_HVS = matrix_HVS.fillna(0)
matrix_HVS = matrix_HVS.round().astype('Int64')
matrix_HVS = matrix_HVS.astype('float')
new_value = 0  # You can set this to any value you want
matrix_HVS = matrix_HVS.applymap(lambda x: new_value if pd.notnull(x) and x <= 30 else x)
matrix_HVS = matrix_HVS.loc[matrix_HVS.sum(axis=1) != 0]

# Remove columns where the sum of elements is zero
matrix_HVS = matrix_HVS.loc[:, matrix_HVS.sum(axis=0) != 0]# Plot heatmap with rigid boxes

import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
matrix_HVS = pd.read_csv("temp/HVS_1_to_7.csv",index_col=0)
sorted_columns = sorted(matrix_HVS.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_HVS.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_HVS=matrix_HVS[sorted_columns]
matrix_HVS = matrix_HVS.loc[sorted_index]
matrix_HVS[matrix_HVS<45] =np.nan
matrix_HVS.drop(matrix_HVS[matrix_HVS.sum(axis=1) == 0].index, inplace=True)
matrix_HVS.drop(matrix_HVS.columns[matrix_HVS.sum(axis=0) == 0], axis=1, inplace=True)
matrix_HVS.columns = ['U1','U2','C3','A4','C5','A6','G7']
matrix_HVS.drop(columns=['U1'],inplace=True)
# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))

heatmap = sns.heatmap(
    matrix_HVS,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=30)  # Adjust tick label size

# Customize title, labels, and ticks
# plt.title("Hbonds between Protein and miRNA for Viron system", fontsize=28)
plt.xticks(fontsize=50, rotation =90)
plt.yticks(fontsize=50, rotation =0)
plt.xlabel('Nucleotides', fontsize=50)
plt.ylabel('Amino Acids', fontsize=50)
# plt.title("miRNA 1 to 7 nucleotides and protein (HSUR)", fontsize=20)
plt.show()
   

plt.show()
# Out:
# C:\Users\17867\AppData\Local\Temp\ipykernel_17692\3450407170.py:30: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   matrix_HVS = matrix_HVS.applymap(lambda x: new_value if pd.notnull(x) and x <= 30 else x)

# %%
matrix_0 = pd.read_csv("temp/HSUR_8_to_21.csv",index_col=0)

sorted_columns = sorted(matrix_0.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_0.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_0=matrix_0[sorted_columns]
matrix_0 = matrix_0.loc[sorted_index]



matrix_0[matrix_0<45] =np.nan
matrix_0.drop(matrix_0[matrix_0.sum(axis=1) == 0].index, inplace=True)
matrix_0.drop(matrix_0.columns[matrix_0.sum(axis=0) == 0], axis=1, inplace=True)
# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
matrix_0.columns = ['U8','G9','G10','C11','G15','U16','C21']
# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))

heatmap = sns.heatmap(
    matrix_0,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=50)  # Adjust tick label size
heatmap.collections[0].set_clim(vmin=0, vmax=200)

# Customize the rest of the plot
plt.xticks(fontsize=50, rotation=90)
plt.yticks(fontsize=50, rotation=0)
plt.xlabel('Nucleotides', fontsize=50)
plt.ylabel('Amino Acids', fontsize=50)
# plt.title("miRNA 8 to 21 nucleotides and protein (HSUR)", fontsize=20)

plt.show()

# %% [markdown]
# ## PIK2

# %%
# PLK2_100[1:]
PLK2_100 = pd.read_csv("../../PIK2_simulations/namd/H-bonds_file/1_to_7_PROA-RNAA_100ns_details.dat", sep='\t')
donor = PLK2_100['donor '].values
donors = []
acceptor = PLK2_100[' acceptor '].values
acceptors = []
for acc in acceptor:
    hyphen_index = acc.index('-')
    acceptors.append(acc[:hyphen_index])
for don in donor:
    #donors.append(don[:-6])
    hyphen_index = don.index('-')
    donors.append(don[:hyphen_index])
Nucleotides = []
for i in range(0,len(donors)):
    Nucleotides.append(donors[i][0:]+"_"+acceptors[i][1:])
PLK2_100['Nucleotides'] = Nucleotides
PLK2_100['Percentage'] = PLK2_100[' occupancy']
components = [x.split('_') for x in PLK2_100['Nucleotides']]

# Create a new DataFrame with the components and 'Percentage' column
new_PLK2_100_0 = pd.DataFrame(components, columns=['Donor', 'Acceptor'])
new_PLK2_100_0['Percentage'] = PLK2_100['Percentage']
new_PLK2_100_0['Percentage'] = new_PLK2_100_0['Percentage'].str.rstrip('%').astype(float)
matrix_PLk2 = new_PLK2_100_0.pivot_table(index='Donor', columns='Acceptor', values='Percentage', aggfunc='mean')
matrix_PLk2 = matrix_PLk2.fillna(0)
matrix_PLk2 = matrix_PLk2.round().astype('Int64')
matrix_PLk2 = matrix_PLk2.astype('float')
new_value = 0  # You can set this to any value you want
matrix_PLk2 = matrix_PLk2.applymap(lambda x: new_value if pd.notnull(x) and x <= 30 else x)
matrix_PLk2 = matrix_PLk2.loc[matrix_PLk2.sum(axis=1) != 0]

# Remove columns where the sum of elements is zero
matrix_PLk2 = matrix_PLk2.loc[:, matrix_PLk2.sum(axis=0) != 0]# Plot heatmap with rigid boxes
plt.figure(figsize=(15, 6))
# heatmap = sns.heatmap(matrix_PLk2, annot=True, cmap='Blues', fmt=".0f", linewidths=1, linecolor='black')
# plt.title("Hbonds between Protein and miRNA for Viron system")
# plt.xticks(fontsize=28)
# plt.yticks(fontsize=28)
# # Setting labels and ticks
# plt.xlabel('Acceptor', fontsize=28)
# plt.ylabel('Donor', fontsize=28)

# import matplotlib.pyplot as plt
# import seaborn as sns

# Plot heatmap with rigid boxes and larger annotation size
plt.figure(figsize=(10, 7))
# matrix_PLk2.columns
column_name = []
row_name = []

for name in matrix_PLk2.index:
    amino_acid = name[0:3]
    row_name.append(three_to_one[amino_acid]+name[3:])

    
for name in matrix_PLk2.columns:
    amino_acid = name[0:3]
    column_name.append(three_to_one[amino_acid]+name[3:])

matrix_PLk2 = np.where(matrix_PLk2 == 0, np.nan, matrix_PLk2)
matrix_PLk2 = pd.DataFrame(matrix_PLk2)
matrix_PLk2.index = row_name
matrix_PLk2.columns = column_name
matrix_PLk2 = pd.read_csv("temp/PLK2_1_to_7.csv",index_col=0)
sorted_columns = sorted(matrix_PLk2.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_PLk2.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_PLk2=matrix_PLk2[sorted_columns]
matrix_PLk2 = matrix_PLk2.loc[sorted_index]
matrix_PLk2[matrix_PLk2<45] =np.nan
matrix_PLk2.drop(matrix_PLk2[matrix_PLk2.sum(axis=1) == 0].index, inplace=True)
matrix_PLk2.drop(matrix_PLk2.columns[matrix_PLk2.sum(axis=0) == 0], axis=1, inplace=True)
# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
matrix_PLk2.columns = ['U1','U2','A4','C5','A6','G7']
matrix_PLk2.drop(columns=['U1'],inplace=True)

# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))

heatmap = sns.heatmap(
    matrix_PLk2,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=30)  # Adjust tick label size

# Customize title, labels, and ticks
# plt.title("Hbonds between Protein and miRNA for Viron system", fontsize=28)
plt.xticks(fontsize=50, rotation =90)
plt.yticks(fontsize=50, rotation =0)
plt.xlabel('Nucleotides', fontsize=50)
plt.ylabel('Amino Acids', fontsize=50)
# plt.title("miRNA 1 to 7 nucleotides and protein (PIK2)", fontsize=20)
plt.show()
   

plt.show()
# Out:
# C:\Users\17867\AppData\Local\Temp\ipykernel_17692\1348009257.py:30: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   matrix_PLk2 = matrix_PLk2.applymap(lambda x: new_value if pd.notnull(x) and x <= 30 else x)

# %%
# seed
ATF3_100 = pd.read_csv("../../PIK2_simulations/namd/H-bonds_file/8_to_21_PROA-RNAA_100ns_details.dat", sep='\t')
donor = ATF3_100['donor '].values
donors = []
acceptor = ATF3_100[' acceptor '].values
acceptors = []
for acc in acceptor:
    hyphen_index = acc.index('-')
    acceptors.append(acc[:hyphen_index])
for don in donor:
    #donors.append(don[:-6])
    hyphen_index = don.index('-')
    donors.append(don[:hyphen_index])
Nucleotides = []
for i in range(0,len(donors)):
    Nucleotides.append(donors[i][0:]+"_"+acceptors[i][1:])
ATF3_100['Nucleotides'] = Nucleotides
ATF3_100['Percentage'] = ATF3_100[' occupancy']
components = [x.split('_') for x in ATF3_100['Nucleotides']]

# Create a new DataFrame with the components and 'Percentage' column
new_ATF3_100_0 = pd.DataFrame(components, columns=['Donor', 'Acceptor'])
new_ATF3_100_0['Percentage'] = ATF3_100['Percentage']
new_ATF3_100_0['Percentage'] = new_ATF3_100_0['Percentage'].str.rstrip('%').astype(float)
matrix_0 = new_ATF3_100_0.pivot_table(index='Donor', columns='Acceptor', values='Percentage', aggfunc='mean')
matrix_0 = matrix_0.fillna(0)
matrix_0 = matrix_0.round().astype('Int64')
matrix_0 = matrix_0.astype('float')
new_value = 0  # You can set this to any value you want
matrix_0 = matrix_0.applymap(lambda x: new_value if pd.notnull(x) and x <= 30 else x)
matrix_0 = matrix_0.loc[matrix_0.sum(axis=1) != 0]

# Remove columns where the sum of elements is zero
matrix_0 = matrix_0.loc[:, matrix_0.sum(axis=0) != 0]# Plot heatmap with rigid boxes
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
# matrix_0 = pd.read_csv("temp/ATF3_8_to_21.csv",index_col=0)

sorted_columns = sorted(matrix_0.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_0.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_0=matrix_0[sorted_columns]
matrix_0 = matrix_0.loc[sorted_index]



matrix_0[matrix_0<45] =np.nan
matrix_0.drop(matrix_0[matrix_0.sum(axis=1) == 0].index, inplace=True)
matrix_0.drop(matrix_0.columns[matrix_0.sum(axis=0) == 0], axis=1, inplace=True)
# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))

heatmap = sns.heatmap(
    matrix_0,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=50)  # Adjust tick label size
heatmap.collections[0].set_clim(vmin=0, vmax=200)

# Customize the rest of the plot
plt.xticks(fontsize=50, rotation=90)
plt.yticks(fontsize=50, rotation=0)
plt.xlabel('Nucleotides', fontsize=50)
plt.ylabel('Amino Acids', fontsize=50)
# plt.title("miRNA 8 to 21 nucleotides and protein (PIK2)", fontsize=20)

plt.show()
# Out:
# C:\Users\17867\AppData\Local\Temp\ipykernel_17692\1873653796.py:30: FutureWarning: DataFrame.applymap has been deprecated. Use DataFrame.map instead.
#   matrix_0 = matrix_0.applymap(lambda x: new_value if pd.notnull(x) and x <= 30 else x)

# %% [markdown]
# ## ATF3

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
matrix_ATF3 = pd.read_csv("temp/ATF3_1_to_7.csv",index_col=0)
sorted_columns = sorted(matrix_ATF3.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_ATF3.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_ATF3=matrix_ATF3[sorted_columns]
matrix_ATF3 = matrix_ATF3.loc[sorted_index]

matrix_ATF3[matrix_ATF3<45] =np.nan
matrix_ATF3.drop(matrix_ATF3[matrix_ATF3.sum(axis=1) == 0].index, inplace=True)
matrix_ATF3.drop(matrix_ATF3.columns[matrix_ATF3.sum(axis=0) == 0], axis=1, inplace=True)
matrix_ATF3.columns = ['U2','A4','C5','A6','G7']
# matrix_ATF3.drop(columns=['U1'],inplace=True)

# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
# Create the heatmap with a colorbar
plt.figure(figsize=(16, 10))

heatmap = sns.heatmap(
    matrix_ATF3,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=30)  # Adjust tick label size

# Customize title, labels, and ticks
# plt.title("Hbonds between Protein and miRNA for Viron system", fontsize=28)
plt.xticks(fontsize=50, rotation =90)
plt.yticks(fontsize=50, rotation =0)
plt.xlabel('Nucleotides', fontsize=50)
plt.ylabel('Amino Acids', fontsize=50)
# plt.title("miRNA 1 to 7 nucleotides and protein (ATF3)", fontsize=20)
plt.show()
   

plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np
matrix_0 = pd.read_csv("temp/ATF3_8_to_21.csv",index_col=0)

sorted_columns = sorted(matrix_0.columns, key=lambda x: int(''.join(filter(str.isdigit, x))))
sorted_index = sorted(matrix_0.index, key=lambda x: int(''.join(filter(str.isdigit, x))))

# Create a DataFrame with sorted columns
matrix_0=matrix_0[sorted_columns]
matrix_0 = matrix_0.loc[sorted_index]



matrix_0[matrix_0<45] =np.nan
matrix_0.drop(matrix_0[matrix_0.sum(axis=1) == 0].index, inplace=True)
matrix_0.drop(matrix_0.columns[matrix_0.sum(axis=0) == 0], axis=1, inplace=True)
matrix_0.columns = ['U8','G9','G10','C11','A13','G15','U17','C18','C19','G20','C21']
# Assuming `three_to_one` is a dictionary mapping three-letter to one-letter amino acid codes
# Create the heatmap with a colorbar
plt.figure(figsize=(20, 12))

heatmap = sns.heatmap(
    matrix_0,
    annot=True,
    cmap='rocket_r',
    fmt=".0f",
    linewidths=1,
    linecolor='black',
    annot_kws={"size": 48, "color": 'white'},  # Adjust the annotation size
    cbar_kws={"shrink": 0.8, "aspect": 30, "label": "", "aspect": 30},  # Adjust colorbar size and add label
    vmin=vmin,
    vmax=vmax,
)

# Customize colorbar tick labels
colorbar = heatmap.collections[0].colorbar
colorbar.ax.tick_params(labelsize=50)  # Adjust tick label size
heatmap.collections[0].set_clim(vmin=0, vmax=200)

# Customize the rest of the plot
plt.xticks(fontsize=50, rotation=90)
plt.yticks(fontsize=50, rotation=0)
plt.xlabel('Nucleotides', fontsize=50)
plt.ylabel('Amino Acids', fontsize=50)
# plt.title("miRNA 8 to 21 nucleotides and protein (ATF3)", fontsize=20)

plt.show()

# %% [markdown]
# # RAMD_Analysis

# %%
Only_miRNA = pd.read_csv("../Only_miRNA/namd/H-bonds_Analysis/I_RAMD/RNAA_RNAB_PROA_hbonds.dat", sep=' ')
rolling_avg_0 = Only_miRNA['count'].rolling(window=10).mean()


Only_miRNA_II = pd.read_csv("../Only_miRNA/namd/H-bonds_Analysis/II_RAMD/PROARNAA_RNAB_hbonds.dat", sep=' ')
rolling_avg_0_II = Only_miRNA_II['count'].rolling(window=10).mean()

Only_miRNA_III = pd.read_csv("../Only_miRNA/namd/H-bonds_Analysis/III_RAMD/RNAA_RNAB_PROA_hbonds.dat", sep=' ')
rolling_avg_0_III = Only_miRNA_III['count'].rolling(window=10).mean()

segment1 = Only_miRNA['frame'].values[0:201] / 2
segment2 = 100+(Only_miRNA['frame'].values[201:]-200)/10
time = np.concatenate((segment1, segment2))
# Generate example data


plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time, rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time, rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time[0:len(Only_miRNA_II)], rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time[0:len(Only_miRNA_II)], rolling_avg_0_II, color='b', alpha=0.5)

plt.scatter(time, rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time, rolling_avg_0_III, color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
# plt.text(90, 37, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
# plt.text(104.5, 37, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

# plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=20)

# Adding a legend
# plt.legend(fontsize=17)


# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently
plt.xlim(40, 120)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=24)

plt.yticks([0,10,20,30,40],fontsize=28)
# plt.ylim(-1.0,40)
# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)
plt.ylim(-1, 40)

plt.tick_params(which='minor', length=4, width=1)
# Show the plot
plt.show()

# %%
viron['count'][0:499]
# Out:
# 0      21
# 1      21
# 2      18
# 3      17
# 4      23
#        ..
# 395     0
# 396     0
# 397     0
# 398     0
# 399     0
# Name: count, Length: 400, dtype: int64

# %%
viron = pd.read_csv("../../viron_simulation/namd/Rerun_I_HPG/H-bonds_file/RNAA_Protein.dat", sep=' ')
rolling_avg_0 = viron['count'].rolling(window=10).mean()


viron_II = pd.read_csv("../../viron_simulation/namd/HPC_rerun/H-bonds-file/RNAA_protein.dat", sep=' ')
rolling_avg_0_II = viron_II['count'].rolling(window=10).mean()

viron_III = pd.read_csv("../../viron_simulation/namd/Rerun_II_HPG/H-bonds_file/RNAA_protein.dat", sep=' ')
rolling_avg_0_III = viron_III['count'].rolling(window=10).mean()



# viron = pd.read_csv("../../viron_simulation/namd/cMD_after_RAMD/Rerun_I_miRNA_protein_hbonds.dat", sep=' ')
# rolling_avg_0 = viron['count'].rolling(window=10).mean()


# viron_II = pd.read_csv("../../viron_simulation/namd/cMD_after_RAMD/Rerun_II_miRNA_protein_hbonds.dat", sep=' ')
# rolling_avg_0_II = viron_II['count'].rolling(window=10).mean()

# viron_III = pd.read_csv("../../viron_simulation/namd/cMD_after_RAMD/Rerun_HPC_miRNA_protein_hbonds.dat", sep=' ')
# rolling_avg_0_III = viron_III['count'].rolling(window=10).mean()

segment1 = viron['frame'].values[0:201] / 2
segment2 = 100+(viron['frame'].values[201:401]-200)/10
time = np.concatenate((segment1, segment2))
viron['time']= time
plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time, rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time, rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time[0:399], rolling_avg_0_II[0:399], color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time[0:399], rolling_avg_0_II[0:399], color='b', alpha=0.5)

plt.scatter(time[0:len(rolling_avg_0_III)], rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time[0:len(rolling_avg_0_III)], rolling_avg_0_III, color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
# plt.text(90, 23, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
# plt.text(102, 23, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

# plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=20)

# Adding a legend
# plt.legend(fontsize=17,frameon=False)

# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently
plt.xlim(40, 120)

plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=24)

plt.yticks([0,10,20,30,40],fontsize=24)
plt.ylim(-1.0,40)
# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)
plt.tick_params(which='minor', length=4, width=1)
# Show the plot
plt.show()

np.mean(viron['count'][119:200].values)
viron_mean = np.sum([viron['count'][0:399], viron_II['count'][0:399], viron_III['count'][0:399]], axis=0) / (3*np.mean(viron['count'][119:200].values)
)
viron_std = np.std([viron['count'][0:399], viron_II['count'][0:399], viron_III['count'][0:399]], axis=0)
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))

viron_mean = pd.Series(viron_mean)  # Example count data
time = viron['time'][0:399]

# Compute rolling average with a window size of 5
rolling_avg = viron_mean.rolling(window=20,center=True).mean()

# Scatter plot for original data
plt.scatter(time[0:399], viron_mean[0:399], color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')

# Line plot for rolling average
plt.plot(time, rolling_avg, color='blue', linewidth=2, label='Rolling Average')
plt.axvline(x=100, color='purple', linestyle='--')

# Add labels, legend, and grid
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Scatter Plot with Rolling Average')
plt.legend(frameon=False)
# plt.grid(True)
plt.xlim(60, 140)
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)
plt.xlim(60, 140)

# Show the plot
plt.show()

# %%
PIK2 = pd.read_csv("../../PIK2_simulations/namd/II_HPG/H-bond/PROA_RNAA_hbonds.dat", sep=' ')
rolling_avg_0 = PIK2['count'].rolling(window=10).mean()


PIK2_II = pd.read_csv("../../PIK2_simulations/namd/III_HPG/H-bond/PROA_RNAA_hbonds.dat", sep=' ')
rolling_avg_0_II = PIK2_II['count'].rolling(window=10).mean()

PIK2_III = pd.read_csv("../../PIK2_simulations/namd/V_HPC/H-bond/PROA_RNAA_hbonds.dat", sep=' ')
rolling_avg_0_III = PIK2_III['count'].rolling(window=10).mean()

segment1 = PIK2['frame'].values[0:201] / 2
segment2 = 100+(PIK2['frame'].values[201:]-200)/10
time = np.concatenate((segment1, segment2))
PIK2['time']= time
plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time, rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time, rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time, rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time, rolling_avg_0_II, color='b', alpha=0.5)

plt.scatter(time[0:len(rolling_avg_0_III)], rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time[0:len(rolling_avg_0_III)], rolling_avg_0_III, color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
# plt.text(90, 23, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
# plt.text(102, 23, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

# plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=20)

# Adding a legend
# plt.legend(fontsize=17,frameon=False)

# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)

# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)
plt.yticks([0,10,20,30,40],fontsize=28)
plt.ylim(-1,40)
# Show the plot
plt.show()

# %%
ATF3 = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RAMD_data/I_Hbond/PROA_RNAA_hbonds.dat", sep=' ')
rolling_avg_0 = ATF3['count'].rolling(window=10).mean()


ATF3_II = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RAMD_data/II_Hbond/PROA_RNAA_hbonds.dat", sep=' ')
rolling_avg_0_II = ATF3_II['count'].rolling(window=10).mean()

ATF3_III = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RAMD_data/III_Hbond/PROA_RNAA_hbonds.dat", sep=' ')
rolling_avg_0_III = ATF3_III['count'].rolling(window=10).mean()

segment1 = ATF3_III['frame'].values[0:201] / 2
segment2 = 100+(ATF3_III['frame'].values[201:]-200)/10
time = np.concatenate((segment1, segment2))
ATF3_III['time']= time


plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time[:ATF3.shape[0]], rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time[:ATF3.shape[0]], rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time[:ATF3_II.shape[0]], rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time[:ATF3_II.shape[0]], rolling_avg_0_II, color='b', alpha=0.5)

plt.scatter(time[:ATF3_III.shape[0]], rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time[:ATF3_III.shape[0]], rolling_avg_0_III, color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
# plt.text(90, 40, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
# plt.text(106, 40, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

# plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=20)

# Adding a legend
# plt.legend(fontsize=17,frameon=False)

# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently
plt.xlim(0, 140)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)

# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)
plt.yticks([0,10,20,30,40],fontsize=28)
plt.ylim(-1,40)
# Show the plot
plt.show()

# %%
np.mean(ATF3['count'][119:200].values)
ATF3_mean = np.sum([ATF3['count'][0:ATF3.shape[0]], ATF3_II['count'][0:ATF3.shape[0]], ATF3_III['count'][0:ATF3.shape[0]]], axis=0) / (3*np.mean(ATF3['count'][119:200].values))
ATF3_std = np.std([ATF3['count'][0:ATF3.shape[0]], ATF3_II['count'][0:ATF3.shape[0]], ATF3_III['count'][0:ATF3.shape[0]]], axis=0)
PIK2_mean = np.sum([PIK2['count'], PIK2_II['count'], PIK2_III['count']], axis=0) / (3*19.56)
PIK2_std = np.std([PIK2['count'], PIK2_II['count'], PIK2_III['count']], axis=0)
PIK2_mean = pd.Series(PIK2_mean)  # Example count data
Only_miRNA_mean = np.sum([Only_miRNA['count'], Only_miRNA_II['count'], Only_miRNA_III['count']], axis=0) / (3*np.mean(Only_miRNA['count'][119:200].values))
Only_miRNA_std = np.std([Only_miRNA['count'], Only_miRNA_II['count'], Only_miRNA_III['count']], axis=0)
Only_miRNA_mean = pd.Series(Only_miRNA_mean)  # Example count data


rolling_avg_miRNA = Only_miRNA_mean.rolling(window=20,center=True).mean()

import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))

ATF3_mean = pd.Series(ATF3_mean)  # Example count data
time = ATF3_III['time'][0:ATF3.shape[0]]

ATF3_std = pd.Series(ATF3_std)  # Example count data
viron_std = pd.Series(viron_std)  # Example count data
PIK2_std = pd.Series(PIK2_std)  # Example count data


# Compute rolling average with a window size of 5
rolling_avg = ATF3_mean.rolling(window=20,center=True).mean()
rolling_avg_viron = viron_mean.rolling(window=20,center=True).mean()
rolling_avg_PIK2 = PIK2_mean.rolling(window=20,center=True).mean()
rolling_avg_miRNA = Only_miRNA_mean.rolling(window=20,center=True).mean()


rolling_std = ATF3_std.rolling(window=20,center=True).mean()
rolling_std_viron = viron_std.rolling(window=20,center=True).mean()
rolling_std_PIK2 = PIK2_std.rolling(window=20,center=True).mean()


# Scatter plot for original data
# plt.scatter(time, ATF3_mean, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')
# plt.scatter(time[0:len(viron_mean)], viron_mean, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')
# plt.scatter(time, PIK2_mean[0:ATF3.shape[0]], color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')

# Line plot for rolling average
plt.plot(time[0:ATF3.shape[0]], rolling_avg_miRNA[0:ATF3.shape[0]], color='red', linewidth=3, label='miRNA only')

plt.plot(time, rolling_avg, color='purple', linewidth=3, label='ATF3')
# plt.fill_between(time, rolling_avg-rolling_std, rolling_avg+rolling_std)

plt.plot(time, rolling_avg_PIK2[0:ATF3.shape[0]], color='green', linewidth=3, label='PIK2')


plt.plot(time[0:len(viron_mean)], rolling_avg_viron, color='k', linewidth=3, label='HSUR1')
plt.plot(time[400:len(viron_mean)], rolling_avg_viron[400:len(viron_mean)], color='grey', linewidth=3, label='HSUR1 cMD following destabalization')
# plt.fill_between(time, rolling_avg_viron-rolling_std_viron, rolling_avg_viron+rolling_std_viron)

# plt.plot(time, rolling_avg_PIK2[0:ATF3.shape[0]], color='green', linewidth=2, label='PIK2')
# plt.fill_between(time, rolling_std_PIK2-rolling_std_PIK2, rolling_std_PIK2+rolling_std_PIK2)


plt.axvline(x=100, color='red', linestyle='--')

# Add labels, legend, and grid
plt.xlabel('Time')
plt.ylabel('Count')
# plt.title('miRNA+target')
plt.legend(fontsize=17, frameon=False)
# plt.grid(True)
plt.xlim(60, 140)
plt.ylabel(r"$\phi$-value (Ago2-miRNA)", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(np.arange(0,2,0.25),fontsize=28)
plt.xlim(100, 140)
plt.ylim(-0.1, 1.1)


# Show the plot
plt.show()

# %% [markdown]
# ## MRNA-miRNA

# %%
# viron = pd.read_csv("../../viron_simulation/namd/Rerun_I_HPG/H-bonds_file/RNAA_RNAB.dat", sep=' ')
# rolling_avg_0 = viron['count'].rolling(window=10).mean()


# viron_II = pd.read_csv("../../viron_simulation/namd/HPC_rerun/H-bonds-file/RNAA_RNAB.dat", sep=' ')
# rolling_avg_0_II = viron_II['count'].rolling(window=10).mean()

# viron_III = pd.read_csv("../../viron_simulation/namd/Rerun_II_HPG/H-bonds_file/RNAA_RNAB.dat", sep=' ')
# rolling_avg_0_III = viron_III['count'].rolling(window=10).mean()


viron = pd.read_csv("../../viron_simulation/namd/HPC_rerun/H-bonds-file/MD_addition_I_RNAA_RNABhbonds.dat", sep=' ')
rolling_avg_0 = viron['count'].rolling(window=10).mean()


viron_III = pd.read_csv("../../viron_simulation/namd/HPC_rerun/H-bonds-file/MD_addition_II_RNAA_RNABhbonds.dat", sep=' ')
rolling_avg_0_III = viron_III['count'].rolling(window=10).mean()

viron_II = pd.read_csv("../../viron_simulation/namd/HPC_rerun/H-bonds-file/MD_addition_HPC_RNAA_RNABhbonds.dat", sep=' ')
rolling_avg_0_II = viron_II['count'].rolling(window=10).mean()


segment1 = viron['frame'].values[0:201] / 2
segment2 = 100+(viron['frame'].values[201:601]-200)/10
time = np.concatenate((segment1, segment2))
viron['time']= time
import numpy as np
import matplotlib.pyplot as plt

# Generate example data


plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time, rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time, rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time, rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time, rolling_avg_0_II, color='b', alpha=0.5)

plt.scatter(time[0:598], rolling_avg_0_III[0:598], color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time[0:598], rolling_avg_0_III[0:598], color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
# plt.text(90, 37, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
# plt.text(102, 37, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

# plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=20)

# Adding a legend
plt.legend(fontsize=17)

# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently
plt.xlim(40, 120)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)

# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)

# Show the plot
plt.show()
np.mean(viron['count'][119:200].values)
viron_mean = np.sum([viron['count'][0:599], viron_II['count'][0:599][0:599], viron_III['count'][0:599]], axis=0) / (3*np.mean(viron['count'][119:200].values))
viron_std = np.std([viron['count'][0:599], viron_II['count'][0:599], viron_III['count'][0:599]], axis=0)
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))

viron_mean = pd.Series(viron_mean)  # Example count data
time = viron['time'][0:599]

# Compute rolling average with a window size of 5
rolling_avg = viron_mean.rolling(window=20,center=True).mean()

# Scatter plot for original data
plt.scatter(time, viron_mean, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')

# Line plot for rolling average
plt.plot(time, rolling_avg, color='blue', linewidth=2, label='Rolling Average')
plt.axvline(x=100, color='purple', linestyle='--')

# Add labels, legend, and grid
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Scatter Plot with Rolling Average')
plt.legend()
# plt.grid(True)
plt.xlim(60, 140)
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)
plt.xlim(60, 140)

# Show the plot
plt.show()

PIK2 = pd.read_csv("../../PIK2_simulations/namd/II_HPG/H-bond/RNAA_RNAB.dat", sep=' ')
rolling_avg_0 = PIK2['count'].rolling(window=10).mean()


PIK2_II = pd.read_csv("../../PIK2_simulations/namd/III_HPG/H-bond/RNAA_RNAB.dat", sep=' ')
rolling_avg_0_II = PIK2_II['count'].rolling(window=10).mean()

PIK2_III = pd.read_csv("../../PIK2_simulations/namd/V_HPC/H-bond/RNAA_RNAB_hbonds.dat", sep=' ')
rolling_avg_0_III = PIK2_III['count'].rolling(window=10).mean()

segment1 = PIK2['frame'].values[0:201] / 2
segment2 = 100+(PIK2['frame'].values[201:]-200)/10
time = np.concatenate((segment1, segment2))
PIK2['time']= time
np.mean(PIK2['count'][119:200].values)
PIK2_mean = np.sum([PIK2['count'], PIK2_II['count'], PIK2_III['count']], axis=0) / (3*np.mean(PIK2['count'][119:200].values)
)
PIK2_std = np.std([PIK2['count'], PIK2_II['count'], PIK2_III['count']], axis=0)
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(12, 6))

PIK2_mean = pd.Series(PIK2_mean)  # Example count data
time = PIK2['time']

# Compute rolling average with a window size of 5
rolling_avg = PIK2_mean.rolling(window=20,center=True).mean()

# Scatter plot for original data
plt.scatter(time, PIK2_mean, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')

# Line plot for rolling average
plt.plot(time, rolling_avg, color='blue', linewidth=2, label='Rolling Average')
plt.axvline(x=100, color='purple', linestyle='--')

# Add labels, legend, and grid
plt.xlabel('Time')
plt.ylabel('Count')
plt.title('Scatter Plot with Rolling Average')
plt.legend()
# plt.grid(True)
plt.xlim(60, 140)
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)
plt.xlim(60, 140)

# Show the plot
plt.show()



import numpy as np
import matplotlib.pyplot as plt

# Generate example data


plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time, rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time, rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time, rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time, rolling_avg_0_II, color='b', alpha=0.5)

plt.scatter(time, rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time, rolling_avg_0_III, color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
plt.text(90, 23, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
plt.text(102, 23, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

plt.title('Hbond variation of AGO2 and miRNA-MRNA [PIK2]', fontsize=20)

# Adding a legend
plt.legend(fontsize=17,frameon=False)

# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)

# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)

# Show the plot
plt.show()
ATF3 = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RAMD_data/I_Hbond/RNAB_RNAA_hbonds.dat", sep=' ')
rolling_avg_0 = ATF3['count'].rolling(window=10).mean()


ATF3_II = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RAMD_data/II_Hbond/RNAB_RNAA_hbonds.dat", sep=' ')
rolling_avg_0_II = ATF3_II['count'].rolling(window=10).mean()

ATF3_III = pd.read_csv("../../Re_Analysis/ATF3/ATF_re_analysis/namd/Analysis_data/RAMD_data/III_Hbond/RNAB_RNAA_hbonds.dat", sep=' ')
rolling_avg_0_III = ATF3_III['count'].rolling(window=10).mean()

segment1 = ATF3_III['frame'].values[0:201] / 2
segment2 = 100+(ATF3_III['frame'].values[201:]-200)/10
time = np.concatenate((segment1, segment2))
ATF3_III['time']= time
# plt.figure(figsize=(10, 6))
# plt.scatter(ATF3_III['time'][0:ATF3.shape[0]], rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')#ATF3_HPG_I
# plt.plot(ATF3_III['time'][0:ATF3.shape[0]], rolling_avg_0, color='r', alpha=0.5)

# plt.scatter(ATF3_III['time'][0:ATF3_II.shape[0]],rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')#ATF3_HPC
# plt.plot(ATF3_III['time'][0:ATF3_II.shape[0]], rolling_avg_0_II, color='b', alpha=0.5)


# plt.scatter(ATF3_III['time'][:ATF3_III.shape[0]], rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')#ATF3_HPG_II
# plt.plot(ATF3_III['time'][:ATF3_III.shape[0]], rolling_avg_0_III, color='g', alpha=0.5)
# # Adding a grid
# plt.grid(True, linestyle='--', alpha=0.7)
# plt.axvline(x=200, color='purple', linestyle='--')
# plt.text(90, 37, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='gold')
# plt.text(102, 37, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='gold')
# plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=12)

# # Adding a legend
# plt.legend(fontsize=17)
# plt.xticks(fontsize=28)
# plt.yticks(fontsize=28)
# # Displaying the plot
# plt.ylabel("H bond counts", fontsize=28)
# plt.xlabel("Time (ns)", fontsize=28)
# # plt.xlim(0,121)
# plt.xticks([0,25,50,100])
# plt.show()
import numpy as np
import matplotlib.pyplot as plt

# Generate example data


plt.figure(figsize=(12, 6))

# Plotting the scatter and lines for different runs
plt.scatter(time[:ATF3.shape[0]], rolling_avg_0, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')  # Viron_HPG_I
plt.plot(time[:ATF3.shape[0]], rolling_avg_0, color='r', alpha=0.5)

plt.scatter(time[:ATF3_II.shape[0]], rolling_avg_0_II, color='b', edgecolor='k', alpha=1, s=20, label='II RAMD run')  # Viron_HPC
plt.plot(time[:ATF3_II.shape[0]], rolling_avg_0_II, color='b', alpha=0.5)

plt.scatter(time[:ATF3_III.shape[0]], rolling_avg_0_III, color='g', edgecolor='k', alpha=1, s=20, label='III RAMD run')  # Viron_HPG_II
plt.plot(time[:ATF3_III.shape[0]], rolling_avg_0_III, color='g', alpha=0.5)

# Adding a grid
plt.grid(True, linestyle='--', alpha=0.7)
plt.axvline(x=100, color='purple', linestyle='--')
# plt.text(90, 52, 'Normal MD', horizontalalignment='right', verticalalignment='center', fontsize=18, color='k')
# plt.text(102, 52, 'RAMD ON', horizontalalignment='left', verticalalignment='center', fontsize=18, color='k')

plt.title('Hbond variation of AGO2 and miRNA-MRNA', fontsize=20)

# Adding a legend
plt.legend(fontsize=17)

# Use a logarithmic scale for x-axis
plt.xscale('linear')

# Set x-axis limits to cover the range more prominently
plt.xlim(0, 140)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(fontsize=28)

# Displaying labels
plt.ylabel("H bond counts", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)
plt.xlim(60, 140)

# Show the plot
plt.show()

# %%
np.mean(ATF3['count'][119:200].values)
ATF3_mean = np.sum([ATF3['count'][0:ATF3.shape[0]], ATF3_II['count'][0:ATF3.shape[0]], ATF3_III['count'][0:ATF3.shape[0]]], axis=0) / (3*np.mean(ATF3['count'][119:200].values))
ATF3_std = np.std([ATF3['count'][0:ATF3.shape[0]], ATF3_II['count'][0:ATF3.shape[0]], ATF3_III['count'][0:ATF3.shape[0]]], axis=0)
import pandas as pd
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 6))

ATF3_mean = pd.Series(ATF3_mean)  # Example count data
time = ATF3_III['time'][0:ATF3.shape[0]]

ATF3_std = pd.Series(ATF3_std)  # Example count data
viron_std = pd.Series(viron_std)  # Example count data
PIK2_std = pd.Series(PIK2_std)  # Example count data


# Compute rolling average with a window size of 5
rolling_avg = ATF3_mean.rolling(window=20,center=True).mean()
rolling_avg_viron = viron_mean.rolling(window=20,center=True).mean()
rolling_avg_PIK2 = PIK2_mean.rolling(window=20,center=True).mean()
# rolling_avg_miRNA = Only_miRNA.rolling(window=20,center=True).mean()


rolling_std = ATF3_std.rolling(window=20,center=True).mean()
rolling_std_viron = viron_std.rolling(window=20,center=True).mean()
rolling_std_PIK2 = PIK2_std.rolling(window=20,center=True).mean()


# Scatter plot for original data
# plt.scatter(time, ATF3_mean, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')
# plt.scatter(time[0:len(viron_mean)], viron_mean, color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')
# plt.scatter(time, PIK2_mean[0:ATF3.shape[0]], color='r', edgecolor='k', alpha=1, s=20, label='I RAMD run')

# Line plot for rolling average
# plt.plot(time, rolling_avg_miRNA, color='red', linewidth=3, label='ATF3')

plt.plot(time, rolling_avg, color='purple', linewidth=3, label='ATF3')
# plt.fill_between(time, rolling_avg-rolling_std, rolling_avg+rolling_std)

plt.plot(time, rolling_avg_PIK2[0:ATF3.shape[0]], color='green', linewidth=3, label='PIK2')


plt.plot(time[0:len(viron_mean)], rolling_avg_viron, color='k', linewidth=3, label='HSUR1')
plt.plot(time[399:len(viron_mean)], rolling_avg_viron[399:len(viron_mean)], color='gray', linewidth=3, label='HSUR1 cMD following destabalization')

# plt.fill_between(time, rolling_avg_viron-rolling_std_viron, rolling_avg_viron+rolling_std_viron)

# plt.plot(time, rolling_avg_PIK2[0:ATF3.shape[0]], color='green', linewidth=2, label='PIK2')
# plt.fill_between(time, rolling_std_PIK2-rolling_std_PIK2, rolling_std_PIK2+rolling_std_PIK2)


plt.axvline(x=100, color='red', linestyle='--')

# Add labels, legend, and grid
plt.xlabel('Time')
plt.ylabel('Count')
# plt.title('miRNA+target')
plt.legend(fontsize=17, frameon=False)
# plt.grid(True)
plt.xlim(60, 140)
plt.ylabel(r"$\phi$-value (miRNA-target)", fontsize=28)
plt.xlabel("Time (ns)", fontsize=28)

# Adjust x-ticks to make sure they cover the whole range
plt.xticks(np.concatenate([np.arange(0, 101, 20), np.arange(100, 141, 20)]), fontsize=28)

plt.yticks(np.arange(0.1,2,0.4),fontsize=28)
plt.yticks(np.arange(0,2,0.25),fontsize=28)
plt.xlim(100, 140)
plt.ylim(-0.1, 1.1)


# Show the plot
plt.show()

# %% [markdown]
# ## C-Alpha analysis

# %%
df = pd.read_csv("output.csv")
plt.figure(figsize=(8, 4))
df['Angle'] = 180-df['Angle']
# Calculate rolling average with a window size of your choice (e.g., window=5)
window_size = 20
df['RollingAvg'] = df['Angle'].rolling(window=window_size).mean()
plt.plot(df.index / 2, df['RollingAvg'], linestyle='-', color='black', label='Only miRNA', linewidth=3)
plt.plot(df.index / 2, df['Angle'], linestyle='-', color='grey', label='Only miRNA', alpha=0.3)
plt.xlim(0,500)
plt.yticks([22,26,30,34])
plt.xlabel('Time(ns)', fontsize=32)
plt.ylabel('Angle(°)', fontsize=32)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
# Out:
# (array([22, 26, 30, 34]),
#  [Text(0, 22, '22'), Text(0, 26, '26'), Text(0, 30, '30'), Text(0, 34, '34')])

# %%
df = pd.read_csv("Only_miRNA_resid_1_to_resid_21_C1'_distance.txt", sep='\t')
plt.figure(figsize=(8, 4))
# df['distance'] = 180-df['distance']
# Calculate rolling average with a window size of your choice (e.g., window=5)
window_size = 20
df['RollingAvg'] = df['distance'].rolling(window=window_size).mean()
plt.plot(df.index / 2, df['RollingAvg'], linestyle='-', color='black', label='Only miRNA',linewidth=3)
plt.plot(df.index / 2, df['distance'], linestyle='-', color='grey', label='Only miRNA', alpha=0.3)
plt.yticks([42,46,50,54])
plt.xlim(0,500)
plt.ylim(40,54)
plt.xlabel('Time(ns)', fontsize=28)
plt.ylabel('Distance(Å)', fontsize=28)
plt.xticks(fontsize=28)
plt.yticks(fontsize=28)
# Out:
# (array([42, 46, 50, 54]),
#  [Text(0, 42, '42'), Text(0, 46, '46'), Text(0, 50, '50'), Text(0, 54, '54')])
